# %%
# Opción 1
edad_usuario = int(input("¿Cuántos años tienes?"))

if edad_usuario < 12:
    print(f"Eres un niño")
elif edad_usuario >=12 and edad_usuario <= 17:
    print(f"Eres un adolescente")
elif edad_usuario >= 18 and edad_usuario <= 64:
    print(f"Eres un adulto")
else:
    print(f"Eres una persona senior")

# ------------------------

# Opción 2
edad_usuario = int(input("¿Cuántos años tienes? "))

if edad_usuario < 12:
    print("Eres un niño")
elif 12 <= edad_usuario <= 17:
    print("Eres un adolescente")
elif 18 <= edad_usuario <= 64:
    print("Eres un adulto")
else:
    print("Eres una persona senior")

# %%
alumno = {
    "nombre": "Carlos",
    "edad": 35,
    "asignaturas": ["Matmáticas", "Programación", "Estadística"]
}

alumno["asignaturas"].append("IA")
alumno["edad"] = 42

print(alumno)

# %%
numero_asignaturas = int(input("Indica el número de asignaturas cursadas"))
lista_asignaturas = []

for i in range(1, numero_asignaturas + 1):
    nombre_asignatura = input(f"Indica el nombre de la asignatura {i}")
    lista_asignaturas.append(nombre_asignatura)

print(f"Tus asignaturas son:")
for asignatura in lista_asignaturas:
    print(asignatura)

# %%
# Opcion 1
ciudades = [" Barcelona ", "madrid", "Valencia", "madrid", " barcelona", "SEVILLA ", "valencia "]
lista_limpia = []
# Eliminar espacios en blanco
for ciudad in ciudades:
    ciudad_limpia = ciudad.strip()
    lista_limpia.append(ciudad_limpia)

print(f"Lista con los valores sin espacios: {lista_limpia}")

# -----------------------------

# Nombres en minúsculas
lista_minusculas = []
for i in lista_limpia:
    minusculas = i.lower()
    lista_minusculas.append(minusculas)

print(f"\nLista en minúsculas: {lista_minusculas}")

# -------------------------

# Ordenar Alfabeticamente
print(f"\nLista ordenada: {sorted(lista_minusculas)}")

# Elminar duplicados
sin_duplicados = list(set(lista_minusculas))
print(f"\nLista sin duplicados: {sin_duplicados}")

# lista final
lista_final = sorted(list(set(lista_minusculas)))
print(f"\nLista limpia, sin duplicados y ordenada: {lista_final}")

# ------------------------

# Opcion 2 
ciudades = [" Barcelona ", "madrid", "Valencia", "madrid", " barcelona", "SEVILLA ", "valencia "]

# Paso 1: limpiar espacios y pasar a minúsculas en la misma lista
for i in range(len(ciudades)):
    ciudades[i] = ciudades[i].strip().lower()

# Paso 2: eliminar duplicados y ordenar
ciudades = sorted(list(set(ciudades)))

print(ciudades)

# %%
correos = [
    "Carlos@gmail.com ", 
    " lucia@Hotmail.com",
    "MARIO@outlook.com",
    "lucia@hotmail.com",
    " ana@GMAIL.com", 
    "carlos@gmail.com"
]

# eliminar espacios, todo en minúsculas, sin duplicados y ordenar

for i in range(len(correos)):
    correos[i] = correos[i].strip().lower()

correos = sorted(list(set(correos)))
print(f"Lista limpia, sin duplicados y ordenada: {correos}")

# %%
nombres = [
    "Carlos", "  ", "lucia", "m4rio", "Ana", "carlos", "ana", "", "Lucia", "   ",
    "juan", "Ju4n", "MARTA", "Marta", "sofia", "sofía"
]

lista_limpia = []

for nombre in nombres:
    nombre = nombre.strip().lower()
    contiene_numero = False
    
    for letra in nombre:
        if letra.isdigit():
            contiene_numero = True
    
    if nombre and not contiene_numero:
        lista_limpia.append(nombre)

lista_limpia = sorted(list(set(lista_limpia)))
print(f"Lista limpia: {lista_limpia}")

# %%
codigos = [
    " AB123 ", "cd456", "EF789", "ab123", "", "  ", "gh!12", "cd456", "ef789", "GH!12", "ij_34", "KL-56", "mnop", "MNOP"
]

lista_limpia = []

for codigo in codigos:
    codigo = codigo.upper().strip()
    if codigo and codigo.isalnum():
        lista_limpia.append(codigo)


lista_limpia = sorted(list(set(lista_limpia)))
print(f"Código limpio: {lista_limpia}")

# %%
codigos = [
    " AB123 ", "cd456", "EF789", "ab123", "", "  ", "gh!12", "cd456", 
    "ef789", "GH!12", "ij_34", "KL-56", "mnop", "MNOP"
]

lista_limpia = []

for codigo in codigos:
    print(f"\nOriginal: '{codigo}'")   # Ver qué llega

    codigo = codigo.upper().strip()
    print(f"Después de .strip().upper(): '{codigo}'")

    if codigo and codigo.isalnum():
        print("✅ Código válido → se añade")
        lista_limpia.append(codigo)
    else:
        print("❌ Código inválido → se descarta")

print("\nResultado final:", lista_limpia)

# %%
productos = ["pan", "leche", "huevos", "galletas"]

# Mostrar cada producto en mayúsculas
for producto in productos:
    producto = producto.upper()
    print(f"Nombre del producto en Mayuscula: {producto}")
print(f"Lista original {productos}")

# 🔹 Solo lectura y visualización
# 	•	Aquí estás recorriendo la lista original con una variable temporal producto.
# 	•	Le aplicas .upper() solo a esa variable, pero no se modifica la lista original.
# 	•	Imprimes el valor modificado, pero cuando el bucle acaba, la lista sigue igual.
# 🧠 Metáfora: es como si ves un objeto, le pones unas gafas para verlo diferente, pero luego no lo tocas.

print("="*30)

# Reescribir la lista convirtiendo cada producto a mayúsculas

for index in range(len(productos)):
    productos[index] = productos[index].upper()

print(f"Nombre del producto en Mayuscula: {productos}")

# 🔹 Modifica la lista Original

print("="*30)

# Mostrar cada producto con su número de posición (empezando en 1)
for index, valor in enumerate(productos, start=1):
    print(f"{index}. {valor}")

# %%
cesta = [
    ("pan", 1.1),
    ("leche", 0.9),
    ("huevos", 2.5),
    ("galletas", 1.8),
    ("leche", 0.9),
    ("pan", 1.1)
]

# Crea una lista sin productos repetidos (por nombre), manteniendo solo uno.
cesta_unica = []
productos_ya_vistos = set()

for producto, precio in cesta:
    if producto not in productos_ya_vistos:
        productos_ya_vistos.add(producto)
        cesta_unica.append((producto, precio))

print(cesta_unica)

# %%
ventas = {
    "Producto A": {
        "cantidad": 10,
        "precio_unitario": 5.0,
        "valor_total":  50.0
    },
    "Producto B": {
        "cantidad": 3,
        "precio_unitario": 12.0,
        "valor_total": 36.0
    },
    "Producto C":{
        "cantidad": 8,
        "precio_unitario": 7.5,
        "valor_total": 60
    }
}

# contar el numoer de productos
print(f"Número de productos: {len(ventas)}")

# Sumatorio de todas las unidades vendidas
total_unidades = 0
suma_precios_unitarios = 0 
for key, value in ventas.items():
    total_unidades += value["cantidad"]
    suma_precios_unitarios += value["precio_unitario"]

precio_unitario_promedio = round(suma_precios_unitarios / len(ventas), 2)

print(f"Unidades Vendidas: {total_unidades}") 
print(f"Promedio Precio Unitario: {precio_unitario_promedio} €")

# %%
inventario = {
    "manzanas": {"stock": 25, "precio": 0.5, "caducado": False},
    "leche": {"stock": 0, "precio": 1.1, "caducado": True},
    "pan": {"stock": 5, "precio": 0.8, "caducado": False},
    "yogur": {"stock": 2, "precio": 0.9, "caducado": True},
    "huevos": {"stock": 12, "precio": 0.2, "caducado": False},
}

# Mostrar cantidad de productos en el inventario
# Calcular el valor total del inventario (solo productos no caducados y con stock > 0)
# Imprimir una lista de productos caducados (solo los nombres).

# Mostrar cantidad de productos en el inventario

print(f"Número de productos en el Inventário: {len(inventario)}")

# Calcular el valor total del inventario (solo productos no caducados y con stock > 0)
valor_total = 0
for key, value in inventario.items():
    if value["caducado"] == False and value["stock"] > 0:
        valor_total += value["stock"] * value["precio"]

print(f"Valor total del inventario: {valor_total:.2f}€")

# Imprimir una lista de productos caducados (solo los nombres).

for key, value in inventario.items():
    if value["caducado"]:
        print(f"Producto caducad: {key}")

# %%
inventario = {
    "manzanas": {"stock": 25, "precio": 0.5, "caducado": False},
    "leche": {"stock": 10, "precio": 1.1, "caducado": False},
    "pan": {"stock": 5, "precio": 0.8, "caducado": False},
    "yogur": {"stock": 7, "precio": 0.9, "caducado": True},
    "huevos": {"stock": 12, "precio": 0.2, "caducado": False},
}

ventas = {
    "manzanas": 10,
    "leche": 5,
    "pan": 3,
    "huevos": 6
}

# 1.	Restar del inventario las unidades vendidas, solo si el producto no está caducado.
# 2.	Mostrar el nuevo inventario (producto y stock actualizado).
# 3.	Mostrar el producto con más stock disponible tras las ventas.
# 4.	Mostrar el producto más caro actualmente (por precio unitario).

for key, value in ventas.items():
    if not inventario[key]["caducado"]:
        inventario[key]["stock"] -= value

# Salida 1 & 2
print(f"Listado de Productos")
print(f"-" * 40)
for producto, datos in inventario.items():
    print(f"Producto: {producto}")
    print(f"    Stock: {datos['stock']}")
    print(f"    Precio: {datos['precio']}")
    print(f"    Caducado: {'Sí' if datos['caducado'] else 'No'}\n")

# 3
mayor_stock = 0
producto_mayor_stock =""
for producto, datos in inventario.items():
    if datos["stock"] > mayor_stock:
        mayor_stock = datos["stock"]
        producto_mayor_stock = producto

print("="*30)
print(f"Producto con mayor Stock")
print(f"\nProducto: {producto_mayor_stock}")
print(f"    Stock: {mayor_stock}")

# 4
mayor_precio = 0
producto_mayor_precio = ""
for producto, datos in inventario.items():
    if datos["precio"] > mayor_precio:
        mayor_precio = datos["precio"]
        producto_mayor_precio = producto

print("="*30)
print(f"Producto con mayor Precio Unitário")
print(f"\nProducto: {producto_mayor_precio}")
print(f"    Precio: {mayor_precio}")

# %%
# EJERCICIO: CALCULADORA DE NOTAS DE UN CURSO

# bjetivo

# Tienes una lista de estudiantes y sus calificaciones en varias asignaturas. El objetivo es calcular:
# 	1.	La media de cada estudiante.
# 	2.	Qué estudiantes han aprobado (media ≥ 5).
# 	3.	Cuál es la media de la clase.
# 	4.	Quién tiene la nota media más alta.

estudiantes = [
    {"nombre": "Carlos", "notas": [7.5, 8.0, 6.5]},
    {"nombre": "Lucía", "notas": [4.0, 5.0, 3.5]},
    {"nombre": "Miguel", "notas": [9.0, 8.5, 9.5]},
    {"nombre": "Sara", "notas": [6.0, 6.5, 7.0]}
]

# 1.- Media de cada estudiante
print(f"\n--- NOTA MEDIA POR ALUMNO ---")
for estudiante in estudiantes:
    nota_media = sum(estudiante["notas"]) / len(estudiante["notas"])
    print(f"• Estudiante: {estudiante['nombre']}\n      Nota Media: {nota_media:.2f}")

print("-"*40)
# 2.- Estudiante que ha aprobado
print(f"\n--- ESTUDIANTES APROBABADOS ---")
for estudiante in estudiantes:
    nota_media = sum(estudiante["notas"]) / len(estudiante["notas"])
    if nota_media >= 5:
        print(f"• Estudiante: {estudiante['nombre']}\n      Nota Media: {nota_media:.2f}")

# 3.- Media de toda la clase
print(f"\n--- NOTA MEDIA CLASE ---")
suma_medias = 0

for estudiante in estudiantes:
    nota_media = sum(estudiante["notas"]) / len(estudiante["notas"])
    suma_medias += nota_media
media_clase = suma_medias / len(estudiantes)
print(f"          {media_clase}")

# 4.- Nota más alta
print(f"\n--- NOTA MEDIA MÁS ALTA ---")
mejor_estudiante = None
mejor_nota = 0

for estudiante in estudiantes:
    nota_media = sum(estudiante["notas"]) / len(estudiante["notas"])
    if nota_media > mejor_nota:
        mejor_nota = nota_media
        mejor_estudiante = estudiante["nombre"]
print(f"• Estudiante: {mejor_estudiante}\n      Nota Media: {mejor_nota:.2f}")
# Out:
# --- NOTA MEDIA POR ALUMNO ---
# • Estudiante: Carlos
#       Nota Media: 7.33
# • Estudiante: Lucía
#       Nota Media: 4.17
# • Estudiante: Miguel
#       Nota Media: 9.00
# • Estudiante: Sara
#       Nota Media: 6.50
# ----------------------------------------
#
# --- ESTUDIANTES APROBABADOS ---
# • Estudiante: Carlos
#       Nota Media: 7.33
# • Estudiante: Miguel
#       Nota Media: 9.00
# • Estudiante: Sara
#       Nota Media: 6.50
#
# --- NOTA MEDIA CLASE ---
#           6.75
#
# --- NOTA MEDIA MÁS ALTA ---
# • Estudiante: Miguel
#       Nota Media: 9.00
